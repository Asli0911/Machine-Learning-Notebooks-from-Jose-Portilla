# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___

# %% [markdown]
# <h1><p style="text-align: center;">Data Analysis with Python <br>Project - 1</p><h1> - Traffic Police Stops <img src="https://docs.google.com/uc?id=17CPCwi3_VvzcS87TOsh4_U8eExOhL6Ki" class="img-fluid" alt="CLRSWY" width="200" height="100">

# %% [markdown]
# Before beginning your analysis, it is critical that you first examine and clean the dataset, to make working with it a more efficient process. You will practice fixing data types, handling missing values, and dropping columns and rows while learning about the Stanford Open Policing Project dataset.

# %% [markdown]
# ***

# %% [markdown]
# ## Examining the dataset

# %% [markdown]
# You'll be analyzing a dataset of traffic stops in Rhode Island that was collected by the Stanford Open Policing Project.

# %% [markdown]
# Before beginning your analysis, it's important that you familiarize yourself with the dataset. You'll read the dataset into pandas, examine the first few rows, and then count the number of missing values.

# %% [markdown]
# **INSTRUCTIONS**
#
# *   Import pandas using the alias ``pd``.
# *   Read the file police.csv into a DataFrame named ``ri``
# *   Examine the first 5 rows of the ``DataFrame`` (known as the ``"head"``).
# *   Count the number of missing values in each column: Use ``.isnull()`` to check which ``DataFrame`` elements are missing, and then take the ``.sum()`` to count the number of ``True`` values in each column.

# %%
import pandas as pd
ri=pd.read_csv('Police.csv')
ri.head()
ri.isnull().sum()
# Out:
# C:\Users\aslik\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (8,16) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# id                            0
# state                         0
# stop_date                    10
# stop_time                    10
# location_raw                  0
# county_name              509681
# county_fips              509681
# fine_grained_location    509681
# police_department            10
# driver_gender             29097
# driver_age_raw            29049
# driver_age                30695
# driver_race_raw           29073
# driver_race               29073
# violation_raw             29073
# violation                 29073
# search_conducted             10
# search_type_raw          491919
# search_type              491919
# contraband_found              0
# stop_outcome              29073
# is_arrested               29073
# stop_duration             29073
# out_of_state              29881
# drugs_related_stop            0
# district                      0
# dtype: int64

# %%
ri.describe().T
# Out:
#                           count         mean         std   min     25%  \
# county_name                 0.0          NaN         NaN   NaN     NaN
# county_fips                 0.0          NaN         NaN   NaN     NaN
# fine_grained_location       0.0          NaN         NaN   NaN     NaN
# driver_age_raw         480632.0  1970.509997  108.187159   0.0  1967.0
# driver_age             478986.0    33.982027   12.702864  15.0    23.0
#
#                           50%     75%     max
# county_name               NaN     NaN     NaN
# county_fips               NaN     NaN     NaN
# fine_grained_location     NaN     NaN     NaN
# driver_age_raw         1980.0  1987.0  8801.0
# driver_age               31.0    43.0    99.0

# %%
ri.count()
# Out:
# id                       509681
# state                    509681
# stop_date                509671
# stop_time                509671
# location_raw             509681
# county_name                   0
# county_fips                   0
# fine_grained_location         0
# police_department        509671
# driver_gender            480584
# driver_age_raw           480632
# driver_age               478986
# driver_race_raw          480608
# driver_race              480608
# violation_raw            480608
# violation                480608
# search_conducted         509671
# search_type_raw           17762
# search_type               17762
# contraband_found         509681
# stop_outcome             480608
# is_arrested              480608
# stop_duration            480608
# out_of_state             479800
# drugs_related_stop       509681
# district                 509681
# dtype: int64

# %% [markdown]
# ***

# %% [markdown]
# ## Dropping columns

# %% [markdown]
# Often, a DataFrame will contain columns that are not useful to your analysis. Such columns should be dropped from the ``DataFrame``, to make it easier for you to focus on the remaining columns.
#
# You'll drop the ``county_name`` column because it only contains missing values, and you'll drop the ``state`` column because all of the traffic stops took place in one state (Rhode Island). Thus, these columns can be dropped because they contain no useful information.

# %% [markdown]
# **INSTRUCTIONS**
#
# *   Examine the ``DataFrame``'s shape to find out the number of rows and columns.
#
# *   Drop the columns that almost consist of missing values.
#
# *   Examine the ``.shape`` again to verify that there are now two fewer columns.

# %%
ri.shape
# Out:
# (509681, 26)

# %%
ri.drop('county_name', axis=1, inplace=True)

# %%
ri.drop(['county_fips', 'fine_grained_location'], axis=1, inplace=True)

# %%
ri.drop('state', axis=1, inplace=True)

# %%
ri.shape
# Out:
# (509681, 22)

# %%
ri.groupby('driver_gender').count()
# Out:
#                    id  stop_date  stop_time  location_raw  police_department  \
# driver_gender
# F              131138     131138     131138        131138             131138
# M              349446     349446     349446        349446             349446
#
#                driver_age_raw  driver_age  driver_race_raw  driver_race  \
# driver_gender
# F                      131137      130828           131138       131138
# M                      349446      348118           349446       349446
#
#                violation_raw  ...  search_conducted  search_type_raw  \
# driver_gender                 ...
# F                     131138  ...            131138             2459
# M                     349446  ...            349446            15303
#
#                search_type  contraband_found  stop_outcome  is_arrested  \
# driver_gender
# F                     2459            131138        131138       131138
# M                    15303            349446        349446       349446
#
#                stop_duration  out_of_state  drugs_related_stop  district
# driver_gender
# F                     131138        130958              131138    131138
# M                     349446        348818              349446    349446
#
# [2 rows x 21 columns]

# %%
ri.head()
# Out:
#               id   stop_date stop_time location_raw police_department  \
# 0  RI-2005-00001  2005-01-02     01:55      Zone K1               600
# 1  RI-2005-00002  2005-01-02     20:30      Zone X4               500
# 2  RI-2005-00003  2005-01-04     11:30      Zone X1                 0
# 3  RI-2005-00004  2005-01-04     12:55      Zone X4               500
# 4  RI-2005-00005  2005-01-06     01:30      Zone X4               500
#
#   driver_gender  driver_age_raw  driver_age driver_race_raw driver_race  ...  \
# 0             M          1985.0        20.0               W       White  ...
# 1             M          1987.0        18.0               W       White  ...
# 2           NaN             NaN         NaN             NaN         NaN  ...
# 3             M          1986.0        19.0               W       White  ...
# 4             M          1978.0        27.0               B       Black  ...
#
#   search_conducted search_type_raw search_type contraband_found stop_outcome  \
# 0            False             NaN         NaN            False     Citation
# 1            False             NaN         NaN            False     Citation
# 2            False             NaN         NaN            False          NaN
# 3            False             NaN         NaN            False     Citation
# 4            False             NaN         NaN            False     Citation
#
#    is_arrested stop_duration out_of_state drugs_related_stop district
# 0        False      0-15 Min        False              False  Zone K1
# 1        False     16-30 Min        False              False  Zone X4
# 2          NaN           NaN          NaN              False  Zone X1
# 3        False      0-15 Min        False              False  Zone X4
# 4        False      0-15 Min        False              False  Zone X4
#
# [5 rows x 22 columns]

# %% [markdown]
# ***

# %% [markdown]
# ## Dropping rows

# %% [markdown]
# When you know that a specific column will be critical to your analysis, and only a small fraction of rows are missing a value in that column, it often makes sense to remove those rows from the dataset.
#
# During this course, the ``driver_gender`` column will be critical to many of your analyses. Because only a small fraction of rows are missing ``driver_gender``, we'll drop those rows from the dataset.

# %% [markdown]
# **INSTRUCTIONS**
#
# *   Count the number of missing values in each column.
#
# *   Drop all rows that are missing ``driver_gender`` by passing the column name to the subset parameter of ``.dropna()``.
# *   Count the number of missing values in each column again, to verify that none of the remaining rows are missing ``driver_gender``.
# *   Examine the ``DataFrame``'s ``.shape`` to see how many rows and columns remain.

# %%
ri.groupby('driver_gender').count()
# Out:
#                    id  stop_date  stop_time  location_raw  police_department  \
# driver_gender
# F              131138     131138     131138        131138             131138
# M              349446     349446     349446        349446             349446
#
#                driver_age_raw  driver_age  driver_race_raw  driver_race  \
# driver_gender
# F                      131137      130828           131138       131138
# M                      349446      348118           349446       349446
#
#                violation_raw  ...  search_conducted  search_type_raw  \
# driver_gender                 ...
# F                     131138  ...            131138             2459
# M                     349446  ...            349446            15303
#
#                search_type  contraband_found  stop_outcome  is_arrested  \
# driver_gender
# F                     2459            131138        131138       131138
# M                    15303            349446        349446       349446
#
#                stop_duration  out_of_state  drugs_related_stop  district
# driver_gender
# F                     131138        130958              131138    131138
# M                     349446        348818              349446    349446
#
# [2 rows x 21 columns]

# %%
ri['driver_gender'].isnull().sum()
# Out:
# 29097

# %%
ri.dropna().shape
# Out:
# (17688, 22)

# %%
ri.dropna(subset=['driver_gender'],inplace=True)

# %%
ri.shape
# Out:
# (480584, 22)

# %%
ri.head()
# Out:
#               id   stop_date stop_time location_raw police_department  \
# 0  RI-2005-00001  2005-01-02     01:55      Zone K1               600
# 1  RI-2005-00002  2005-01-02     20:30      Zone X4               500
# 3  RI-2005-00004  2005-01-04     12:55      Zone X4               500
# 4  RI-2005-00005  2005-01-06     01:30      Zone X4               500
# 5  RI-2005-00006  2005-01-12     08:05      Zone X1                 0
#
#   driver_gender  driver_age_raw  driver_age driver_race_raw driver_race  ...  \
# 0             M          1985.0        20.0               W       White  ...
# 1             M          1987.0        18.0               W       White  ...
# 3             M          1986.0        19.0               W       White  ...
# 4             M          1978.0        27.0               B       Black  ...
# 5             M          1973.0        32.0               B       Black  ...
#
#   search_conducted search_type_raw search_type contraband_found stop_outcome  \
# 0            False             NaN         NaN            False     Citation
# 1            False             NaN         NaN            False     Citation
# 3            False             NaN         NaN            False     Citation
# 4            False             NaN         NaN            False     Citation
# 5            False             NaN         NaN            False     Citation
#
#    is_arrested stop_duration out_of_state drugs_related_stop district
# 0        False      0-15 Min        False              False  Zone K1
# 1        False     16-30 Min        False              False  Zone X4
# 3        False      0-15 Min        False              False  Zone X4
# 4        False      0-15 Min        False              False  Zone X4
# 5        False       30+ Min         True              False  Zone X1
#
# [5 rows x 22 columns]

# %%
ri.index
# Out:
# Int64Index([     0,      1,      3,      4,      5,      6,      7,      8,
#                  9,     10,
#             ...
#             509661, 509662, 509663, 509664, 509665, 509666, 509667, 509668,
#             509669, 509670],
#            dtype='int64', length=480584)

# %%
type(ri)
# Out:
# pandas.core.frame.DataFrame

# %%
ri.head()
# Out:
#               id   stop_date stop_time location_raw police_department  \
# 0  RI-2005-00001  2005-01-02     01:55      Zone K1               600
# 1  RI-2005-00002  2005-01-02     20:30      Zone X4               500
# 3  RI-2005-00004  2005-01-04     12:55      Zone X4               500
# 4  RI-2005-00005  2005-01-06     01:30      Zone X4               500
# 5  RI-2005-00006  2005-01-12     08:05      Zone X1                 0
#
#   driver_gender  driver_age_raw  driver_age driver_race_raw driver_race  ...  \
# 0             M          1985.0        20.0               W       White  ...
# 1             M          1987.0        18.0               W       White  ...
# 3             M          1986.0        19.0               W       White  ...
# 4             M          1978.0        27.0               B       Black  ...
# 5             M          1973.0        32.0               B       Black  ...
#
#   search_conducted search_type_raw search_type contraband_found stop_outcome  \
# 0            False             NaN         NaN            False     Citation
# 1            False             NaN         NaN            False     Citation
# 3            False             NaN         NaN            False     Citation
# 4            False             NaN         NaN            False     Citation
# 5            False             NaN         NaN            False     Citation
#
#    is_arrested stop_duration out_of_state drugs_related_stop district
# 0        False      0-15 Min        False              False  Zone K1
# 1        False     16-30 Min        False              False  Zone X4
# 3        False      0-15 Min        False              False  Zone X4
# 4        False      0-15 Min        False              False  Zone X4
# 5        False       30+ Min         True              False  Zone X1
#
# [5 rows x 22 columns]

# %%
ri.groupby('police_department').count()
# Out:
#                       id  stop_date  stop_time  location_raw  driver_gender  \
# police_department
# 0                  11415      11415      11415         11415          11415
# 1                     11         11         11            11             11
# 2                      2          2          2             2              2
# 3                     13         13         13            13             13
# 4                      3          3          3             3              3
# ...                  ...        ...        ...           ...            ...
# 600                13533      13533      13533         13533          13533
# 900                15209      15209      15209         15209          15209
# K2                     1          1          1             1              1
# MA                     1          1          1             1              1
# OUT                    1          1          1             1              1
#
#                    driver_age_raw  driver_age  driver_race_raw  driver_race  \
# police_department
# 0                           11415       11378            11415        11415
# 1                              11          11               11           11
# 2                               2           2                2            2
# 3                              13          13               13           13
# 4                               3           3                3            3
# ...                           ...         ...              ...          ...
# 600                         13533       13473            13533        13533
# 900                         15209       15179            15209        15209
# K2                              1           1                1            1
# MA                              1           1                1            1
# OUT                             1           1                1            1
#
#                    violation_raw  ...  search_conducted  search_type_raw  \
# police_department                 ...
# 0                          11415  ...             11415              264
# 1                             11  ...                11                0
# 2                              2  ...                 2                0
# 3                             13  ...                13                0
# 4                              3  ...                 3                1
# ...                          ...  ...               ...              ...
# 600                        13533  ...             13533              355
# 900                        15209  ...             15209              608
# K2                             1  ...                 1                0
# MA                             1  ...                 1                0
# OUT                            1  ...                 1                0
#
#                    search_type  contraband_found  stop_outcome  is_arrested  \
# police_department
# 0                          264             11415         11415        11415
# 1                            0                11            11           11
# 2                            0                 2             2            2
# 3                            0                13            13           13
# 4                            1                 3             3            3
# ...                        ...               ...           ...          ...
# 600                        355             13533         13533        13533
# 900                        608             15209         15209        15209
# K2                           0                 1             1            1
# MA                           0                 1             1            1
# OUT                          0                 1             1            1
#
#                    stop_duration  out_of_state  drugs_related_stop  district
# police_department
# 0                          11415         11340               11415     11415
# 1                             11            11                  11        11
# 2                              2             2                   2         2
# 3                             13            13                  13        13
# 4                              3             3                   3         3
# ...                          ...           ...                 ...       ...
# 600                        13533         13529               13533     13533
# 900                        15209         15193               15209     15209
# K2                             1             1                   1         1
# MA                             1             1                   1         1
# OUT                            1             1                   1         1
#
# [73 rows x 21 columns]

# %%
ri['driver_age_raw'].min()
# Out:
# 0.0

# %%
ri['driver_age_raw'].max()
# Out:
# 8801.0

# %%
ri['driver_age_raw'].mean()
# Out:
# 1970.542156089583

# %%
ri.shape
# Out:
# (480584, 22)

# %%
ri['driver_gender'].isnull().sum()
# Out:
# 0

# %%
ri.head()
# Out:
#               id   stop_date stop_time location_raw police_department  \
# 0  RI-2005-00001  2005-01-02     01:55      Zone K1               600
# 1  RI-2005-00002  2005-01-02     20:30      Zone X4               500
# 3  RI-2005-00004  2005-01-04     12:55      Zone X4               500
# 4  RI-2005-00005  2005-01-06     01:30      Zone X4               500
# 5  RI-2005-00006  2005-01-12     08:05      Zone X1                 0
#
#   driver_gender  driver_age_raw  driver_age driver_race_raw driver_race  ...  \
# 0             M          1985.0        20.0               W       White  ...
# 1             M          1987.0        18.0               W       White  ...
# 3             M          1986.0        19.0               W       White  ...
# 4             M          1978.0        27.0               B       Black  ...
# 5             M          1973.0        32.0               B       Black  ...
#
#   search_conducted search_type_raw search_type contraband_found stop_outcome  \
# 0            False             NaN         NaN            False     Citation
# 1            False             NaN         NaN            False     Citation
# 3            False             NaN         NaN            False     Citation
# 4            False             NaN         NaN            False     Citation
# 5            False             NaN         NaN            False     Citation
#
#    is_arrested stop_duration out_of_state drugs_related_stop district
# 0        False      0-15 Min        False              False  Zone K1
# 1        False     16-30 Min        False              False  Zone X4
# 3        False      0-15 Min        False              False  Zone X4
# 4        False      0-15 Min        False              False  Zone X4
# 5        False       30+ Min         True              False  Zone X1
#
# [5 rows x 22 columns]

# %% [markdown]
# ***

# %% [markdown]
# ## Fixing a data type

# %% [markdown]
# We know that the ``is_arrested`` column currently has the ``object`` data type. In this exercise, we'll change the data type to ``bool``, which is the most suitable type for a column containing ``True`` and ``False`` values.
#
# Fixing the data type will enable us to use mathematical operations on the ``is_arrested`` column that would not be possible otherwise.

# %% [markdown]
# **INSTRUCTIONS**
#
# *   Examine the head of the ``is_arrested`` column to verify that it contains ``True`` and ``False`` values.
# *   Check the current data type of ``is_arrested``.
# *   Use the ``.astype()`` method to convert ``is_arrested`` to a ``bool`` column.
# *   Check the new data type of ``is_arrested``, to confirm that it is now a ``bool`` column.

# %%
ri['is_arrested'].head()
# Out:
# 0    False
# 1    False
# 3    False
# 4    False
# 5    False
# Name: is_arrested, dtype: object

# %%
ri['is_arrested'].dtype
# Out:
# dtype('O')

# %%
ri.dtypes
# Out:
# id                     object
# stop_date              object
# stop_time              object
# location_raw           object
# police_department      object
# driver_gender          object
# driver_age_raw        float64
# driver_age            float64
# driver_race_raw        object
# driver_race            object
# violation_raw          object
# violation              object
# search_conducted       object
# search_type_raw        object
# search_type            object
# contraband_found         bool
# stop_outcome           object
# is_arrested            object
# stop_duration          object
# out_of_state           object
# drugs_related_stop       bool
# district               object
# dtype: object

# %%
ri['is_arrested']=ri['is_arrested'].astype(bool)

# %%
ri['is_arrested'].head()
# Out:
# 0    False
# 1    False
# 3    False
# 4    False
# 5    False
# Name: is_arrested, dtype: bool

# %%
ri['is_arrested'].dtype
# Out:
# dtype('bool')

# %% [markdown]
# ***

# %% [markdown]
# ## Combining object columns

# %% [markdown]
# Currently, the date and time of each traffic stop are stored in separate object columns: ``stop_date`` and ``stop_time``.
#
# You'll combine these two columns into a single column, and then convert it to ``datetime`` format. This will enable convenient date-based attributes that we'll use later in the course.

# %% [markdown]
# **INSTRUCTIONS**
#
# *    Use a string method to concatenate ``stop_date`` and ``stop_time`` (separated by a space), and store the result in ``combined``.
# *    Convert ``combined`` to ``datetime`` format, and store the result in a new column named ``stop_datetime``.
# *    Examine the ``DataFrame`` ``.dtypes`` to confirm that ``stop_datetime`` is a datetime column.

# %%
ri['combined']= ri['stop_date']+' ' +ri['stop_time']
ri.head()
# Out:
#               id   stop_date stop_time location_raw police_department  \
# 0  RI-2005-00001  2005-01-02     01:55      Zone K1               600
# 1  RI-2005-00002  2005-01-02     20:30      Zone X4               500
# 3  RI-2005-00004  2005-01-04     12:55      Zone X4               500
# 4  RI-2005-00005  2005-01-06     01:30      Zone X4               500
# 5  RI-2005-00006  2005-01-12     08:05      Zone X1                 0
#
#   driver_gender  driver_age_raw  driver_age driver_race_raw driver_race  ...  \
# 0             M          1985.0        20.0               W       White  ...
# 1             M          1987.0        18.0               W       White  ...
# 3             M          1986.0        19.0               W       White  ...
# 4             M          1978.0        27.0               B       Black  ...
# 5             M          1973.0        32.0               B       Black  ...
#
#   search_type_raw search_type contraband_found stop_outcome is_arrested  \
# 0             NaN         NaN            False     Citation       False
# 1             NaN         NaN            False     Citation       False
# 3             NaN         NaN            False     Citation       False
# 4             NaN         NaN            False     Citation       False
# 5             NaN         NaN            False     Citation       False
#
#    stop_duration out_of_state  drugs_related_stop district          combined
# 0       0-15 Min        False               False  Zone K1  2005-01-02 01:55
# 1      16-30 Min        False               False  Zone X4  2005-01-02 20:30
# 3       0-15 Min        False               False  Zone X4  2005-01-04 12:55
# 4       0-15 Min        False               False  Zone X4  2005-01-06 01:30
# 5        30+ Min         True               False  Zone X1  2005-01-12 08:05
#
# [5 rows x 23 columns]

# %%
ri.shape
# Out:
# (480584, 24)

# %%
ri.dtypes
# Out:
# id                            object
# stop_date                     object
# stop_time                     object
# location_raw                  object
# police_department             object
# driver_gender                 object
# driver_age_raw               float64
# driver_age                   float64
# driver_race_raw               object
# driver_race                   object
# violation_raw                 object
# violation                     object
# search_conducted              object
# search_type_raw               object
# search_type                   object
# contraband_found                bool
# stop_outcome                  object
# is_arrested                     bool
# stop_duration                 object
# out_of_state                  object
# drugs_related_stop              bool
# district                      object
# combined                      object
# stop_datetime         datetime64[ns]
# dtype: object

# %%
ri['stop_datetime']=ri['combined'].astype('datetime64')

# %%
ri.dtypes
# Out:
# id                            object
# stop_date                     object
# stop_time                     object
# location_raw                  object
# police_department             object
# driver_gender                 object
# driver_age_raw               float64
# driver_age                   float64
# driver_race_raw               object
# driver_race                   object
# violation_raw                 object
# violation                     object
# search_conducted              object
# search_type_raw               object
# search_type                   object
# contraband_found                bool
# stop_outcome                  object
# is_arrested                     bool
# stop_duration                 object
# out_of_state                  object
# drugs_related_stop              bool
# district                      object
# combined                      object
# stop_datetime         datetime64[ns]
# dtype: object

# %% [markdown]
# The last step that you'll take in this chapter is to set the ``stop_datetime`` column as the ``DataFrame``'s index. By replacing the default index with a ``DatetimeIndex``, you'll make it easier to analyze the dataset by date and time, which will come in handy later in the course.

# %% [markdown]
# **INSTRUCTIONS**
#
# *   Set ``stop_datetime`` as the ``DataFrame`` index.
# *   Examine the index to verify that it is a ``DatetimeIndex``.
# *   Examine the ``DataFrame`` columns to confirm that ``stop_datetime`` is no longer one of the columns.

# %%
ri.index=ri['stop_datetime']

# %%
ri.drop('combined', axis=1, inplace=True)
ri.head()
# Out:
#                                 id   stop_date stop_time location_raw  \
# stop_datetime
# 2005-01-02 01:55:00  RI-2005-00001  2005-01-02     01:55      Zone K1
# 2005-01-02 20:30:00  RI-2005-00002  2005-01-02     20:30      Zone X4
# 2005-01-04 12:55:00  RI-2005-00004  2005-01-04     12:55      Zone X4
# 2005-01-06 01:30:00  RI-2005-00005  2005-01-06     01:30      Zone X4
# 2005-01-12 08:05:00  RI-2005-00006  2005-01-12     08:05      Zone X1
#
#                     police_department driver_gender  driver_age_raw  \
# stop_datetime
# 2005-01-02 01:55:00               600             M          1985.0
# 2005-01-02 20:30:00               500             M          1987.0
# 2005-01-04 12:55:00               500             M          1986.0
# 2005-01-06 01:30:00               500             M          1978.0
# 2005-01-12 08:05:00                 0             M          1973.0
#
#                      driver_age driver_race_raw driver_race  ...  \
# stop_datetime                                                ...
# 2005-01-02 01:55:00        20.0               W       White  ...
# 2005-01-02 20:30:00        18.0               W       White  ...
# 2005-01-04 12:55:00        19.0               W       White  ...
# 2005-01-06 01:30:00        27.0               B       Black  ...
# 2005-01-12 08:05:00        32.0               B       Black  ...
#
#                     search_conducted search_type_raw search_type  \
# stop_datetime
# 2005-01-02 01:55:00            False             NaN         NaN
# 2005-01-02 20:30:00            False             NaN         NaN
# 2005-01-04 12:55:00            False             NaN         NaN
# 2005-01-06 01:30:00            False             NaN         NaN
# 2005-01-12 08:05:00            False             NaN         NaN
#
#                     contraband_found stop_outcome  is_arrested stop_duration  \
# stop_datetime
# 2005-01-02 01:55:00            False     Citation        False      0-15 Min
# 2005-01-02 20:30:00            False     Citation        False     16-30 Min
# 2005-01-04 12:55:00            False     Citation        False      0-15 Min
# 2005-01-06 01:30:00            False     Citation        False      0-15 Min
# 2005-01-12 08:05:00            False     Citation        False       30+ Min
#
#                      out_of_state drugs_related_stop district
# stop_datetime
# 2005-01-02 01:55:00         False              False  Zone K1
# 2005-01-02 20:30:00         False              False  Zone X4
# 2005-01-04 12:55:00         False              False  Zone X4
# 2005-01-06 01:30:00         False              False  Zone X4
# 2005-01-12 08:05:00          True              False  Zone X1
#
# [5 rows x 22 columns]
